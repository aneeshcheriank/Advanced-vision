# %% [markdown]
# <a href="https://colab.research.google.com/github/aneeshcheriank/Advanced-vision/blob/main/Selective_search_to_generate_Region_Proposals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q selectivesearch
# !pip install -q torch_snippets
from torch_snippets import *
import selectivesearch
from skimage.segmentation import felzenszwalb

# %%
# Fetch and load the required images
# !wget https://www.dropbox.com/s/1981eemr7r5stnm/Hemanvi.jpeg
# the image is not working so loading an image from the dir
from google.colab import files
file_name = files.upload()
for file in file_name.keys():
  img = read(file, 1)
  break

import matplotlib.pyplot as plt
plt.figure(figsize=(4, 4))
plt.imshow(img)
plt.axis(False)
plt.show()
# Out:
#      <input type="file" id="files-f6467fc1-b827-4cec-bed4-ac51f063fa06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6467fc1-b827-4cec-bed4-ac51f063fa06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images (7).jpeg to images (7) (2).jpeg

# %% [markdown]
# ## Extract felzenszwalb segments
# - based on color, texture, size, and shape

# %%
segments_fz = felzenszwalb(img, scale=200)
# scale represent the number of clusters

# plot the original imag and the image with segmentation
subplots(
  [img, segments_fz],
  titles = ['Original Image', 'Image post segmentation'],
  sz=10, nc=2
)
